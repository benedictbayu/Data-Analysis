# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os
print('\n'.join(os.listdir(r'./drive/My Drive/Colab Test (Bootcamp ML 2020)')))
# Out:
# References
# Untitled0.ipynb
# Week_1_Python_1.ipynb
# heart.csv
# iris.csv
# pima-indians-diabetes.csv
# sonar.csv

# %%
df = pd.read_csv(r'./drive/My Drive/Colab Test (Bootcamp ML 2020)/sonar.csv')
df.head()
# Out:
#        V1      V2      V3      V4  ...     V58     V59     V60  Class
# 0  0.0200  0.0371  0.0428  0.0207  ...  0.0084  0.0090  0.0032      1
# 1  0.0453  0.0523  0.0843  0.0689  ...  0.0049  0.0052  0.0044      1
# 2  0.0262  0.0582  0.1099  0.1083  ...  0.0164  0.0095  0.0078      1
# 3  0.0100  0.0171  0.0623  0.0205  ...  0.0044  0.0040  0.0117      1
# 4  0.0762  0.0666  0.0481  0.0394  ...  0.0048  0.0107  0.0094      1
#
# [5 rows x 61 columns]

# %%
df.shape
# Out:
# (208, 61)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 208 entries, 0 to 207
# Data columns (total 61 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   V1      208 non-null    float64
#  1   V2      208 non-null    float64
#  2   V3      208 non-null    float64
#  3   V4      208 non-null    float64
#  4   V5      208 non-null    float64
#  5   V6      208 non-null    float64
#  6   V7      208 non-null    float64
#  7   V8      208 non-null    float64
#  8   V9      208 non-null    float64
#  9   V10     208 non-null    float64
#  10  V11     208 non-null    float64
#  11  V12     208 non-null    float64
#  12  V13     208 non-null    float64
#  13  V14     208 non-null    float64
#  14  V15     208 non-null    float64
#  15  V16     208 non-null    float64
#  16  V17     208 non-null    float64
#  17  V18     208 non-null    float64
#  18  V19     208 non-null    float64
#  19  V20     208 non-null    float64
# ...

# %%
#Cek Missing Values
pd.set_option('display.max_rows', 100)
print(df.isnull().sum())
print('\nTerdapat {} Missing Values pada Dataset'.format(df.isnull().sum().sum()))
# Out:
# V1       0
# V2       0
# V3       0
# V4       0
# V5       0
# V6       0
# V7       0
# V8       0
# V9       0
# V10      0
# V11      0
# V12      0
# V13      0
# V14      0
# V15      0
# V16      0
# V17      0
# V18      0
# V19      0
# V20      0
# V21      0
# V22      0
# V23      0
# V24      0
# V25      0
# V26      0
# V27      0
# V28      0
# V29      0
# V30      0
# V31      0
# V32      0
# V33      0
# V34      0
# V35      0
# V36      0
# V37      0
# V38      0
# V39      0
# V40      0
# V41      0
# V42      0
# V43      0
# V44      0
# V45      0
# V46      0
# V47      0
# V48      0
# V49      0
# V50      0
# V51      0
# V52      0
# V53      0
# V54      0
# V55      0
# V56      0
# V57      0
# V58      0
# V59      0
# V60      0
# Class    0
# dtype: int64
#
# Terdapat 0 Missing Values pada Dataset

# %%
pd.set_option('display.max_rows', 100)
df.describe().T
# Out:
#        count      mean       std     min       25%      50%       75%     max
# V1     208.0  0.029164  0.022991  0.0015  0.013350  0.02280  0.035550  0.1371
# V2     208.0  0.038437  0.032960  0.0006  0.016450  0.03080  0.047950  0.2339
# V3     208.0  0.043832  0.038428  0.0015  0.018950  0.03430  0.057950  0.3059
# V4     208.0  0.053892  0.046528  0.0058  0.024375  0.04405  0.064500  0.4264
# V5     208.0  0.075202  0.055552  0.0067  0.038050  0.06250  0.100275  0.4010
# V6     208.0  0.104570  0.059105  0.0102  0.067025  0.09215  0.134125  0.3823
# V7     208.0  0.121747  0.061788  0.0033  0.080900  0.10695  0.154000  0.3729
# V8     208.0  0.134799  0.085152  0.0055  0.080425  0.11210  0.169600  0.4590
# V9     208.0  0.178003  0.118387  0.0075  0.097025  0.15225  0.233425  0.6828
# V10    208.0  0.208259  0.134416  0.0113  0.111275  0.18240  0.268700  0.7106
# V11    208.0  0.236013  0.132705  0.0289  0.129250  0.22480  0.301650  0.7342
# ...

# %%
df['Class'].value_counts()
# Out:
# 0    111
# 1     97
# Name: Class, dtype: int64

# %% [markdown]
# Mengganti 0 dengan Mines dan 1 dengan Rock

# %%
df['Class'] = df['Class'].replace(0, 'M')
df['Class'] = df['Class'].replace(1, 'R')

# %%
df.head()
# Out:
#        V1      V2      V3      V4      V5  ...     V57     V58     V59     V60  Class
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  ...  0.0180  0.0084  0.0090  0.0032      R
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  ...  0.0140  0.0049  0.0052  0.0044      R
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  ...  0.0316  0.0164  0.0095  0.0078      R
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  ...  0.0050  0.0044  0.0040  0.0117      R
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  ...  0.0072  0.0048  0.0107  0.0094      R
#
# [5 rows x 61 columns]

# %%
#Cek distribusi kelas
plt.figure(figsize=(7, 5))
sns.countplot(df['Class'], palette='Paired')
plt.title('Distribusi Kelas', fontsize=15)
plt.show()

# %%
#Cek korelasinya
plt.figure(figsize=(30, 20))
sns.heatmap(df.corr(), annot=False)
plt.title('Korelasi tiap atribut/feature dari Dataset', fontsize=20)
plt.show()

# %% [markdown]
# Mayoritas dari atribut/feature tidak terlalu berkorelasi

# %% [markdown]
# **Machine Learning Model**
#
# **Data Preprocessing**

# %%
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier

from sklearn.preprocessing import StandardScaler, PowerTransformer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, f1_score, recall_score, confusion_matrix, classification_report

# %%
X = df.drop(['Class'], axis=1)
y = df['Class']

# %%
scaler = StandardScaler()
scaler2 = PowerTransformer(method='yeo-johnson', standardize=True)
X_scaled = scaler.fit_transform(X.values)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((166, 60), (42, 60), (166,), (42,))

# %% [markdown]
# Support Vector Machine Classifier

# %%
types = ['rbf', 'poly', 'linear']
for i in types:
  svmc = SVC(kernel=i)
  svmc.fit(X_train, y_train)
  prediksi_svc = svmc.predict(X_train)
  prediksi_svc_test = svmc.predict(X_test)
  y_pred_svm = svmc.predict(X_test)
  cm = confusion_matrix(y_test, y_pred_svm)
  print('Nilai Akurasi SVC pada Training Set dengan Kernel = {}'.format(i), 'adalah', round(accuracy_score(prediksi_svc, y_train), 2))
  print('Nilai Akurasi SVC pada Testing Set dengan Kernel = {}'.format(i), 'adalah', round(accuracy_score(prediksi_svc_test, y_test), 2), '\n')
  print(classification_report(y_test, y_pred_svm))
  print(cm)
  print('=======================================================================================================================================')
# Out:
# Nilai Akurasi SVC pada Training Set dengan Kernel = rbf adalah 0.98
# Nilai Akurasi SVC pada Testing Set dengan Kernel = rbf adalah 0.9
#
#               precision    recall  f1-score   support
#
#            M       0.96      0.88      0.92        26
#            R       0.83      0.94      0.88        16
#
#     accuracy                           0.90        42
#    macro avg       0.90      0.91      0.90        42
# weighted avg       0.91      0.90      0.91        42
#
# [[23  3]
#  [ 1 15]]
# ...
# Nilai Akurasi SVC pada Training Set dengan Kernel = poly adalah 0.99
# Nilai Akurasi SVC pada Testing Set dengan Kernel = poly adalah 0.9
#
#               precision    recall  f1-score   support
#
#            M       0.96      0.88      0.92        26
#            R       0.83      0.94      0.88        16
#
#     accuracy                           0.90        42
#    macro avg       0.90      0.91      0.90        42
# weighted avg       0.91      0.90      0.91        42
#
# [[23  3]
# ...

# %% [markdown]
# Nilai akurasi dari Model SVC terbaik diperoleh dengan Kernel Polynomial dengan nilai akurasi sebesar 0.9

# %% [markdown]
# K-Nearest Neighbors

# %%
neig = np.arange(1, 26, 2)
train_accuracy = []
test_accuracy = []

for i, k in enumerate(neig):
  knn = KNeighborsClassifier(n_neighbors=k)
  knn.fit(X_train, y_train)
  train_accuracy.append(knn.score(X_train, y_train))
  test_accuracy.append(knn.score(X_test, y_test))

plt.figure(figsize=[10,8])
plt.plot(neig, test_accuracy, label = 'Testing Accuracy')
plt.plot(neig, train_accuracy, label = 'Training Accuracy')
plt.legend()
plt.title('-value VS Accuracy')
plt.xlabel('Number of Neighbors')
plt.ylabel('Accuracy')
plt.xticks(neig)
plt.grid()
plt.show()
print("\nNilai Akurasi terbaik untuk Model KNN adalah {} dengan nilai K = {}".format(round(np.max(test_accuracy), 2), 2+test_accuracy.index(np.max(test_accuracy))))
# Out:
# Nilai Akurasi terbaik untuk Model KNN adalah 0.95 dengan nilai K = 3

# %%
neig = np.arange(1, 26, 2)
f1_train_accuracy = []
f1_test_accuracy = []

for i, k in enumerate(neig):
  knn = KNeighborsClassifier(n_neighbors=k)
  knn.fit(X_train, y_train)
  prediksi_knn_train = knn.predict(X_train)
  prediksi_knn_test = knn.predict(X_test)
  f1_train_accuracy.append(f1_score(y_train, prediksi_knn_train, average='macro'))
  f1_test_accuracy.append(f1_score(y_test, prediksi_knn_test, average='macro'))

plt.figure(figsize=[10,8])
plt.plot(neig, f1_test_accuracy, label = 'F1 Testing Accuracy')
plt.plot(neig, f1_train_accuracy, label = 'F1 Training Accuracy')
plt.legend()
plt.title('-value VS Accuracy')
plt.xlabel('Number of Neighbors')
plt.ylabel('Accuracy')
plt.xticks(neig)
plt.grid()
plt.show()
print("\nNilai F1 Score terbaik untuk Model KNN adalah {} dengan nilai K = {}".format(round(np.max(f1_test_accuracy),2),2+f1_test_accuracy.index(np.max(f1_test_accuracy))))
# Out:
# Nilai F1 Score terbaik untuk Model KNN adalah 0.95 dengan nilai K = 3

# %%
neig = np.arange(1, 26, 2)
precision_train_accuracy = []
precision_test_accuracy = []

for i, k in enumerate(neig):
  knn = KNeighborsClassifier(n_neighbors=k)
  knn.fit(X_train, y_train)
  prediksi_knn_train = knn.predict(X_train)
  prediksi_knn_test = knn.predict(X_test)
  precision_train_accuracy.append(precision_score(y_train, prediksi_knn_train, average='macro'))
  precision_test_accuracy.append(precision_score(y_test, prediksi_knn_test, average='macro'))

plt.figure(figsize=[10,8])
plt.plot(neig, precision_test_accuracy, label = 'Precision Testing Accuracy')
plt.plot(neig, precision_train_accuracy, label = 'Precision Training Accuracy')
plt.legend()
plt.title('-value VS Accuracy')
plt.xlabel('Number of Neighbors')
plt.ylabel('Accuracy')
plt.xticks(neig)
plt.grid()
plt.show()
print("\nNilai Precision terbaik untuk Model KNN adalah {} untuk nilai K = {}".format(round(np.max(precision_test_accuracy), 2),2+precision_test_accuracy.index(np.max(precision_test_accuracy))))
# Out:
# Nilai Precision terbaik untuk Model KNN adalah 0.94 untuk nilai K = 3

# %%
neig = np.arange(1, 26, 2)
recall_train_accuracy = []
recall_test_accuracy = []

for i, k in enumerate(neig):
  knn = KNeighborsClassifier(n_neighbors=k)
  knn.fit(X_train, y_train)
  prediksi_knn_train = knn.predict(X_train)
  prediksi_knn_test = knn.predict(X_test)
  recall_train_accuracy.append(recall_score(y_train, prediksi_knn_train, average='macro'))
  recall_test_accuracy.append(recall_score(y_test, prediksi_knn_test, average='macro'))

plt.figure(figsize=[10,8])
plt.plot(neig, recall_test_accuracy, label = 'Recall Testing Accuracy')
plt.plot(neig, recall_train_accuracy, label = 'Recall Training Accuracy')
plt.legend()
plt.title('-value VS Accuracy')
plt.xlabel('Number of Neighbors')
plt.ylabel('Accuracy')
plt.xticks(neig)
plt.grid()
plt.show()
print("\nNilai Recall Score terbaik untuk Model KNN adalah {} dengan K = {}".format(round(np.max(recall_test_accuracy),2),2+recall_test_accuracy.index(np.max(recall_test_accuracy))))
# Out:
# Nilai Recall Score terbaik untuk Model KNN adalah 0.96 dengan K = 3

# %% [markdown]
# Random Forest Classifier

# %%
estimator = [50, 100, 200, 300]
for i in estimator:
  rf = RandomForestClassifier(n_estimators=i, max_depth=5)
  rf.fit(X_train, y_train)
  prediksi_rf = rf.predict(X_train)
  prediksi_rf_test = rf.predict(X_test)
  y_pred_rf = rf.predict(X_test)
  cm = confusion_matrix(y_test, y_pred_rf)
  print('Nilai Akurasi Random Forest pada Training Set dengan n_estimator = {}'.format(i), 'adalah', round(accuracy_score(prediksi_rf, y_train), 2))
  print('Nilai Akurasi Random Forest pada Testing Set dengan n_estimator = {}'.format(i), 'adalah', round(accuracy_score(prediksi_rf_test, y_test), 2), '\n')
  print(classification_report(y_test, y_pred_rf))
  print(cm)
  print('=======================================================================================================================================')
# Out:
# Nilai Akurasi Random Forest pada Training Set dengan n_estimator = 50 adalah 1.0
# Nilai Akurasi Random Forest pada Testing Set dengan n_estimator = 50 adalah 0.74
#
#               precision    recall  f1-score   support
#
#            M       0.86      0.69      0.77        26
#            R       0.62      0.81      0.70        16
#
#     accuracy                           0.74        42
#    macro avg       0.74      0.75      0.73        42
# weighted avg       0.77      0.74      0.74        42
#
# [[18  8]
#  [ 3 13]]
# ...
# Nilai Akurasi Random Forest pada Training Set dengan n_estimator = 100 adalah 1.0
# Nilai Akurasi Random Forest pada Testing Set dengan n_estimator = 100 adalah 0.86
#
#               precision    recall  f1-score   support
#
#            M       0.95      0.81      0.88        26
#            R       0.75      0.94      0.83        16
#
#     accuracy                           0.86        42
#    macro avg       0.85      0.87      0.85        42
# ...

# %% [markdown]
# Nilai akurasi terbaik dengan Model Random Forest diperoleh dengan n_estimator = 200, dengan nilai akurasi sebesar 0.86

# %% [markdown]
# Quadratic Discriminant Analysis

# %%
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

# %%
quad = QuadraticDiscriminantAnalysis()
quad.fit(X_train, y_train)
prediksi_quad = quad.predict(X_train)
prediksi_quad_test = quad.predict(X_test)
y_pred_quad = quad.predict(X_test)
cm = confusion_matrix(y_test, y_pred_quad)
print('Nilai Akurasi Quadratic Discriminant Analysis pada Training Set adalah', round(accuracy_score(prediksi_quad, y_train), 2))
print('Nilai Akurasi Quadratic Discriminant Analysis pada Testing Set adalah', round(accuracy_score(prediksi_quad_test, y_test), 2), '\n')
print(classification_report(y_test, y_pred_quad))
print(cm)
# Out:
# Nilai Akurasi Quadratic Discriminant Analysis pada Training Set adalah 1.0
# Nilai Akurasi Quadratic Discriminant Analysis pada Testing Set adalah 0.67
#
#               precision    recall  f1-score   support
#
#            M       0.75      0.69      0.72        26
#            R       0.56      0.62      0.59        16
#
#     accuracy                           0.67        42
#    macro avg       0.65      0.66      0.65        42
# weighted avg       0.68      0.67      0.67        42
#
# [[18  8]
#  [ 6 10]]

# %% [markdown]
# Logistic Regression

# %%
lr = LogisticRegression()
lr.fit(X_train, y_train)
prediksi_lr = lr.predict(X_train)

# %%
print(f1_score(y_train, prediksi_lr, average='macro'))
print(precision_score(y_train, prediksi_lr, average='macro'))
print(recall_score(y_train, prediksi_lr, average='macro'))
# Out:
# 0.9337325349301397
# 0.9339430894308942
# 0.9341321713870734

# %%
prediksi_lr = lr.predict(X_test)

print('Akurasi Logistic Regression pada Testing Set adalah :', round(lr.score(X_test, y_test),2))
print(f1_score(y_test, prediksi_lr, average='macro'))
print(precision_score(y_test, prediksi_lr, average='macro'))
print(recall_score(y_test, prediksi_lr, average='macro'))
# Out:
# Akurasi Logistic Regression pada Testing Set adalah : 0.81
# 0.8055555555555555
# 0.8045454545454545
# 0.8221153846153846

# %%
y_pred_lr = lr.predict(X_test)
cm = confusion_matrix(y_test, y_pred_lr)
print(classification_report(y_test, y_pred_lr), '\n')
print(cm)
# Out:
#               precision    recall  f1-score   support
#
#            M       0.91      0.77      0.83        26
#            R       0.70      0.88      0.78        16
#
#     accuracy                           0.81        42
#    macro avg       0.80      0.82      0.81        42
# weighted avg       0.83      0.81      0.81        42
#
#
# [[20  6]
#  [ 2 14]]

# %% [markdown]
# Decision Tree Classifier

# %%
kriteria = ['gini', 'entropy']
for i in kriteria:
  tree_c = DecisionTreeClassifier(criterion=i, random_state=42)
  tree_c.fit(X_train, y_train)
  prediksi_tree = tree_c.predict(X_train)
  prediksi_tree_test = tree_c.predict(X_test)
  y_pred_tree = tree_c.predict(X_test)
  cm = confusion_matrix(y_test, y_pred_tree)
  print('Nilai Akurasi Decision Tree pada Training Set dengan criterion = {}'.format(i), 'adalah', round(accuracy_score(prediksi_tree, y_train), 2))
  print('Nilai Akurasi Decision Tree pada Testing Set dengan criterion = {}'.format(i), 'adalah', round(accuracy_score(prediksi_tree_test, y_test), 2), '\n')
  print(classification_report(y_test, y_pred_tree))
  print(cm)
  print('=======================================================================================================================================')
# Out:
# Nilai Akurasi Decision Tree pada Training Set dengan criterion = gini adalah 1.0
# Nilai Akurasi Decision Tree pada Testing Set dengan criterion = gini adalah 0.71
#
#               precision    recall  f1-score   support
#
#            M       0.79      0.73      0.76        26
#            R       0.61      0.69      0.65        16
#
#     accuracy                           0.71        42
#    macro avg       0.70      0.71      0.70        42
# weighted avg       0.72      0.71      0.72        42
#
# [[19  7]
#  [ 5 11]]
# ...
# Nilai Akurasi Decision Tree pada Training Set dengan criterion = entropy adalah 1.0
# Nilai Akurasi Decision Tree pada Testing Set dengan criterion = entropy adalah 0.74
#
#               precision    recall  f1-score   support
#
#            M       0.89      0.65      0.76        26
#            R       0.61      0.88      0.72        16
#
#     accuracy                           0.74        42
#    macro avg       0.75      0.76      0.74        42
# ...

# %% [markdown]
# Nilai akurasi tertinggi untuk Model Decision Tree diperoleh dengan Criterion entropy dengan nilai akurasi sebesar 0.74
